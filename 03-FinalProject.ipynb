# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Regional and Institutional Differences in SAT Math and Verbal Scores and Their Relationship to Admissions Outcomes (2023)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [ 'X' ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# This project examines whether SAT Math and SAT Verbal median scores differ across U.S. regions and between public and private universities in 2023, and how these differences are related to admissions outcomes. Understanding these patterns is important because standardized test scores continue to play a role in college admissions, even in the context of test-optional policies. Prior research suggests that SAT performance is shaped not only by individual academic ability but also by regional inequalities in educational resources and differences in institutional selectivity. As a result, comparing SAT score distributions across regions and institution types can provide insight into how structural and institutional factors are reflected in admissions-related metrics.
#
# To investigate this question, we used a dataset containing university-level information on median SAT Math and Verbal scores, institutional characteristics (including region and public vs. private status), and admissions outcomes such as acceptance rates. We conducted exploratory data analysis to compare score distributions across groups and to examine patterns of variation between Math and Verbal components. In addition, we analyzed how these score differences are associated with admissions outcomes by comparing acceptance rates across categories. This approach allows us to examine how academic metrics and institutional factors are related within the broader admissions landscape, without assuming a single underlying cause for observed differences.

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Team list and credits:
# - Yuchen Hou: Background research, Writing – original draft
# - Minkyung Gwak: Methodology, Writing – original draft
# - Nicolas Leedy: Analysis, Writing – original draft
# - Mowen Tan: Conceptualization, Writing – original draft, Writing – review & editing
# - Iris Liu: Conceptualization, Writing – original draft, Writing – review & editing

# %% [markdown]
# ## Research Question

# %% [markdown]
# Are SAT Math and SAT Verbal medians significantly different across U.S. regions and between public vs. private universities in 2023, and how are admission outcomes related?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Admission decisions in U.S. higher education are shaped by the interaction of academic metrics, institutional selectivity, and broader structural inequalities. Among these factors, standardized test scores—particularly SAT Math and Evidence-Based Reading and Writing (Verbal)—have long served as key indicators of college readiness. Although many universities adopted test-optional policies by 2023, SAT scores remain widely reported and continue to influence both applicant strategies and institutional decision-making. As a result, examining variation in SAT Math and Verbal median scores across U.S. regions and between public and private universities provides a useful lens for understanding differences in academic preparation as well as patterns of admissions selectivity. Institutional datasets, such as those compiled by the University of California system, demonstrate how admissions outcomes (e.g., acceptance rates) can be analyzed alongside applicant academic characteristics, enabling integrated examination of both inputs and outcomes in the admissions process.<a href="#ref1">1</a>
#
# A central insight from prior research is that SAT scores are not purely measures of individual academic ability but are strongly shaped by contextual factors. Recent large-scale analyses show that school-level and regional characteristics—including funding disparities, demographic composition, and access to college preparatory resources—significantly influence average SAT performance across geographic areas.<a href="#ref4">4</a> These findings suggest that observed regional differences in SAT Math and Verbal scores may reflect unequal access to educational opportunities rather than intrinsic differences in student ability, which is important for interpreting score variation within a broader structural context. Complementary evidence from University of California–focused research further indicates that socioeconomic background variables, such as family income and parental education, account for a substantial portion of variation in SAT scores and have become increasingly correlated with test performance over time.<a href="#ref5">5</a> Together, these studies highlight the importance of considering underlying structural factors when comparing SAT medians across regions.
#
# Institutional context introduces an additional dimension to the interpretation of SAT score distributions. Public and private universities differ in their missions, applicant pools, and enrollment priorities, which may influence both observed score distributions and admissions outcomes. Research on highly selective private institutions shows that geographic and informational barriers can limit applications from high-achieving, low-income students, even when their SAT scores are competitive.<a href="#ref6">6</a> This suggests that differences in SAT medians across institution types may arise not only from selectivity but also from variation in applicant pool composition and recruitment practices. Considering these factors is important for understanding how institutional structures shape both who applies and how academic metrics are represented among admitted students.
#
# At the same time, the role of SAT scores in admissions decisions has evolved in recent years. Policy-oriented analyses emphasize a shift toward holistic and contextualized evaluation, in which test scores are considered alongside GPA, coursework rigor, and indicators of socioeconomic background.<a href="#ref2">2</a> However, empirical evidence indicates that SAT scores continue to function as meaningful signals in the admissions process. For example, recent findings from the National Bureau of Economic Research show that submitting standardized test scores can increase admission probabilities, particularly for students from disadvantaged backgrounds.<a href="#ref7">7</a> This suggests that even in test-optional contexts, SAT scores may still play a role in shaping admissions outcomes, making it relevant to examine how score distributions relate to measures such as acceptance rates.
#
# In addition to their role in admissions, standardized test scores are also associated with post-enrollment academic performance. Research from Opportunity Insights finds that SAT and ACT scores are predictive of college grades, although their predictive strength varies across institutions and student populations.<a href="#ref3">3</a> These findings indicate that SAT scores capture certain dimensions of academic preparation, while also reflecting broader contextual influences. Moreover, differences between SAT Math and Verbal components may represent distinct aspects of student preparation, which could vary across regions or institutional contexts due to differences in curriculum emphasis or educational resources.
#
# Taken together, prior work suggests that both regional context and institutional characteristics shape observed SAT score distributions, but potentially through different mechanisms. Regional variation is often associated with differences in educational resources and opportunity structures, while institutional differences may reflect selection processes and applicant pool composition. This distinction is important for framing comparisons of SAT medians across regions and institution types, as it highlights multiple factors that may contribute to observed patterns.
#
# Despite extensive research on standardized testing, several gaps remain. First, much of the literature focuses on composite SAT scores rather than explicitly comparing Math and Verbal components, limiting understanding of subject-specific variation. Second, prior studies often examine score distributions or admissions outcomes separately, rather than considering how they relate to one another. Third, while regional disparities and institutional differences are well documented independently, their interaction in shaping both SAT medians and admissions outcomes remains less explored in recent data.
#
# Building on this literature, this project investigates whether SAT Math and SAT Verbal median scores differ significantly across U.S. regions and between public and private universities in 2023, and how these differences relate to admissions outcomes such as acceptance rates. By examining these factors jointly, the analysis aims to better understand how academic metrics, regional context, and institutional characteristics are associated within the broader admissions landscape.
#
# References
#
# <a name="ref1">1</a> University of California Office of the President. Admissions Outcomes and Performance
# https://www.ucop.edu/institutional-research-academic-planning/_files/admissions-outcomes-and-performance.pdf
#
# <a name="ref2">2</a> College Board. Beyond the Admission Decision: New Trends in Test Score Use (March 2024)
# https://highered.collegeboard.org/media/pdf/Beyond%20the%20Admission%20Decision%20%20New%20Trends%20in%20Test%20Score%20Use%20%20March%202024.pdf
#
# <a name="ref3">3</a> Opportunity Insights. SAT/ACT Scores and College Grades
# https://opportunityinsights.org/wp-content/uploads/2024/01/SAT_ACT_on_Grades.pdf
#
# <a name="ref4">4</a> Liu, M., & Lu, W. (2026). A Multifaceted Analysis of School-Level Factors for Average SAT Score Disparities Across Diverse Regions
# https://www.mdpi.com/2227-7102/16/2/289
#
# <a name="ref5">5</a> Geiser, S. The Growing Correlation Between Race and SAT Scores: New Findings from California
# https://cshe.berkeley.edu/publications/growing-correlation-between-race-and-sat-scores-new-findings-california-saul-geiser
#
# <a name="ref6">6</a> Hoxby, C., & Avery, C. Low-income Students and Highly Selective Private Colleges: Geography, Searching, and Recruiting
# https://www.sciencedirect.com/science/article/abs/pii/S0272775710000026
#
# <a name="ref7">7</a> National Bureau of Economic Research. Test-Optional Policies and Disadvantaged Students
# https://www.nber.org/digest/202504/test-optional-policies-and-disadvantaged-students

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that SAT Math and SAT Verbal median scores differ significantly across U.S. regions and between public and private universities in 2023. Specifically, we expect private universities to report higher median SAT scores than public universities, and we also expect measurable regional differences in both SAT components. This expectation follows from the fact that institutions differ in their applicant pools and levels of selectivity, and those differences may be reflected in the SAT profiles they report.
#
# We also hypothesize that admission outcomes will be related to these SAT patterns. In particular, we expect universities with higher SAT Math and Verbal medians to have lower admission rates, because institutions with stronger reported SAT profiles are often more selective. Finally, we expect the size of the public-private SAT gap to vary across regions rather than remain constant nationwide, which would suggest that institutional type and geographic context are connected rather than acting independently.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: IPEDS Admissions Data 2023 (Revised Values)
#
#   - Link to the dataset: https://nces.ed.gov/ipeds/Search?query=&query2=&resultType=all&page=1&sortBy=date_desc&surveyComponents=Admissions%20(ADM)&collectionYears=2023-24
#
#   - Number of observations: 1,973 universities
#
#   - Number of variables: 101 columns
#
#   - Description of the variables most relevant to this project
# 	- UNITID: Unique school identifier used to merge datasets.
#     - SATMT50: Median SAT Math section score for reported students (points, 200-800 scale).
#     - SATVR50: Median SAT Verbal/Reading section score (used as SAT verbal proxy; points, 200-800 scale).
#     - SATPCT: Percent of enrolled first-time students who submitted SAT scores (0-100).
#     - SATMT25, SATMT75, SATVR25, SATVR75: 25th and 75th percentile SAT section scores.
#     - APPLCN, ADMSSN, ENRLT: Applications, admissions, and enrollments (counts; used for context/quality checks).
#     - X... columns (example XSATMT50): reporting/status flags for corresponding metrics.
#
#    - Description of of any shortcomings this dataset has with respect to the project: SAT values are missing for many schools (especially under test-optional policies), so analysis sample is smaller after filtering. Data are school-level aggregates, not student-level observations; results are associative, not causal.
#
#
# - Dataset #2
#   - Dataset Name: IPEDS Institutional Characteristics / Header Data 2023
#
#   - Link to the dataset: https://nces.ed.gov/ipeds/Search?query=&query2=&resultType=all&page=1&sortBy=date_desc&surveyComponents=Admissions%20(ADM)&collectionYears=2023-24
#
#   - Number of observations: 6,163 institutions
#
#   - Number of variables: 73 columns
#
#   - Description of the variables most relevant to this project
# 	- UNITID: Unique school identifier used to merge with admissions data.
# 	- INSTNM: Institution name.
# 	- STABBR: State abbreviation.
# 	- OBEREG: Region code (used to build Northeast/Midwest/South/West groups).
# 	- CONTROL: Institution control (1 Public, 2 Private nonprofit, 3 Private for-profit), collapsed to Public vs Private in cleaning.
# 	- Other metadata fields exist (location, sector, size, URLs), but are not central to the main question.
#
# - Descriptions of any shortcomings this dataset has with respect to the project: Region is coded numerically and must be recoded carefully to avoid misclassification.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/COGS108/Group065_WI26/master/data/00-raw/adm2023_RV.csv', 'filename': 'adm2023_RV.csv' },
    { 'url': 'https://raw.githubusercontent.com/COGS108/Group065_WI26/master/data/00-raw/hd2023.csv', 'filename': 'hd2023.csv' }
]

get_data.get_raw(datafiles, destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress:  50%|█████     | 1/2 [00:00<00:00,  3.29it/s]A
# Successfully downloaded: adm2023_RV.csv
# ...
# Overall Download Progress: 100%|██████████| 2/2 [00:05<00:00,  2.85s/it]
# Successfully downloaded: hd2023.csv

# %% [markdown]
# ### University Admissions and SAT Outcomes by Region and Institution Type (IPEDS 2023 Combined Dataset)
#
# This project combines two raw IPEDS 2023 files because neither file alone is sufficient for our research question. The admissions file (`adm2023_RV.csv`) contains SAT and admissions outcome variables but does not include the full contextual labels needed for grouped comparisons. The institutional header/characteristics file (`hd2023.csv`) provides those context variables, including institution name, state, region code, and control type. We merge these two sources by `UNITID` (IPEDS institution ID), so each final row still represents one institution but now includes both outcomes and grouping variables required for analysis.
#
# The key outcome metrics are `SATMT50` and `SATVR50`, which are median SAT Math and SAT Verbal/Reading section scores at each institution. These are measured in SAT section points, where valid section values are generally between 200 and 800. We also retain `SATMT25`, `SATMT75`, `SATVR25`, and `SATVR75` to represent score spread within institutions. For admissions context, we keep `APPLCN` (number of applicants), `ADMSSN` (number admitted), and `ENRLT` (number enrolled), which are count variables. We also use `SATPCT` (0–100), the percentage of enrolled first-time students who submitted SAT scores, to evaluate how representative SAT statistics are at each institution.
#
# The grouping variables come from institutional characteristics. `CONTROL` identifies institution control (public, private nonprofit, private for-profit), and `OBEREG` is the IPEDS region code. For this project, `OBEREG` is mapped to four broader U.S. regions (Northeast, Midwest, South, West). We also collapse institution control to `Public` vs `Private`. The reason is both conceptual and practical: after filtering out schools without usable SAT medians, one private subgroup (especially private for-profit) has very few institutions left, which makes separate subgroup comparisons unstable and noisy. Combining nonprofit and for-profit into a single private category gives more reliable group sizes for statistical comparison.
#
# There are important limitations and potential biases. First, this is school-level aggregated data rather than student-level data, so analyses identify institutional associations rather than individual-level causal effects. Second, SAT fields have substantial missingness, likely related to test-optional and reporting practices, so missingness is probably systematic rather than random; this can bias the final sample. Third, `SATVR50` represents verbal/reading performance, not a direct writing score, so conclusions should use official variable definitions. Finally, collapsing private institution types improves stability but can hide differences between private nonprofit and private for-profit schools.

# %%
import pandas as pd
import numpy as np

# Load raw files
adm = pd.read_csv("data/00-raw/adm2023_RV.csv", low_memory=False)
hd = pd.read_csv("data/00-raw/hd2023.csv", low_memory=False)

# Merge admissions with institution metadata
df_withoutadm = adm.merge(
    hd[["UNITID", "INSTNM", "STABBR", "OBEREG", "CONTROL"]],
    on="UNITID",
    how="left"
)

print("Raw shape:", df_withoutadm.shape)
print("\nMissingness (%):")
print((df_withoutadm.isna().mean() * 100).sort_values(ascending=False).round(2))

# Keep columns used for analysis
df_withoutadm = df_withoutadm[[
    "UNITID", "INSTNM", "STABBR", "OBEREG", "CONTROL",
    "APPLCN", "ADMSSN", "ENRLT", "SATPCT",
    "SATVR50", "SATMT50", "SATVR25", "SATVR75", "SATMT25", "SATMT75"
]].copy()

# Convert numeric columns
num_cols = ["APPLCN", "ADMSSN", "ENRLT", "SATPCT", "SATVR50", "SATMT50", "SATVR25", "SATVR75", "SATMT25", "SATMT75"]
for c in num_cols:
    df_withoutadm[c] = pd.to_numeric(df_withoutadm[c], errors="coerce")

# Collapse control into Public vs Private only
df_withoutadm["control_group"] = df_withoutadm["CONTROL"].map({1: "Public", 2: "Private", 3: "Private"})

# Build 4-region labels from OBEREG
region_map = {
    1: "Northeast", 2: "Northeast",
    3: "Midwest", 4: "Midwest",
    5: "South", 6: "South",
    7: "West", 8: "West",
    9: "Outlying"
}
df_withoutadm["region"] = df_withoutadm["OBEREG"].map(region_map)

# Drop schools without SAT medians and keep valid groups
df_withoutadm_clean = df_withoutadm.dropna(subset=["SATMT50", "SATVR50"]).copy()
df_withoutadm_clean = df_withoutadm_clean[df_withoutadm_clean["control_group"].isin(["Public", "Private"])].copy()
df_withoutadm_clean = df_withoutadm_clean[df_withoutadm_clean["region"].isin(["Northeast", "Midwest", "South", "West"])].copy()

# Keep SAT values in valid section-score range
df_withoutadm_clean = df_withoutadm_clean[
    df_withoutadm_clean["SATMT50"].between(200, 800) &
    df_withoutadm_clean["SATVR50"].between(200, 800)
].copy()

# Optional context metrics
df_withoutadm_clean["admit_rate"] = np.where(df_withoutadm_clean["APPLCN"] > 0, df_withoutadm_clean["ADMSSN"] / df_withoutadm_clean["APPLCN"], np.nan)
df_withoutadm_clean["yield_rate"] = np.where(df_withoutadm_clean["ADMSSN"] > 0, df_withoutadm_clean["ENRLT"] / df_withoutadm_clean["ADMSSN"], np.nan)

# Save cleaned data
df_withoutadm_final = df_withoutadm_clean.drop(columns=["CONTROL", "OBEREG"], errors="ignore")
df_withoutadm_final.to_csv("data/02-processed/university_sat_region_control_2023.csv", index=False)


print(df_withoutadm_clean.shape)
df_withoutadm_final.head()
# Out:
# Raw shape: (1973, 105)
#
# Missingness (%):
# ENRLPTAN     96.45
# ENRLFTAN     95.13
# ENRLAN       92.90
# ADMSSNAN     92.45
# APPLCNAN     76.03
#              ...
# XENRLT        0.00
# XADMSSNUN     0.00
# XADMSSNAN     0.00
# XADMSSNW      0.00
# CONTROL       0.00
# Length: 105, dtype: float64
# (983, 19)
#    UNITID                               INSTNM STABBR  APPLCN   ADMSSN  \
# 0  100654             Alabama A & M University     AL   15628  10349.0
# 1  100663  University of Alabama at Birmingham     AL   10919   9655.0
# 2  100706  University of Alabama in Huntsville     AL    6074   4510.0
# 3  100724             Alabama State University     AL    5346   5113.0
# 4  100751            The University of Alabama     AL   58418  44295.0
#
#     ENRLT  SATPCT  SATVR50  SATMT50  SATVR25  SATVR75  SATMT25  SATMT75  \
# 0  1956.0    24.0    480.0    460.0    420.0    540.0    390.0    520.0
# 1  2095.0     5.0    640.0    620.0    580.0    700.0    570.0    700.0
# ...

# %% [markdown]
# # Results
# We conducted our results section in 3 parts. First, we looked at the relationship between SAT scores and Admissions rate by using scatter plots and correlation tests. Second, we tested the variance of this relationship between public and private institutions using linear regression and scatter plots again. Third, we analyzed how SAT score regional varianced differed between public and private universities.

# %% [raw]
# ### DF LOAD

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# Load processed dataset
df_withoutadm = pd.read_csv("data/02-processed/university_sat_region_control_2023.csv")

# Keep ordered categories for cleaner plots
region_order = ["Northeast", "Midwest", "South", "West"]
control_order = ["Public", "Private"]
df_withoutadm = df_withoutadm[df_withoutadm["region"].isin(region_order) & df_withoutadm["control_group"].isin(control_order)].copy()
df_withoutadm["region"] = pd.Categorical(df_withoutadm["region"], categories=region_order, ordered=True)
df_withoutadm["control_group"] = pd.Categorical(df_withoutadm["control_group"], categories=control_order, ordered=True)

print("Analysis shape:", df_withoutadm.shape)
display(df_withoutadm[["UNITID", "INSTNM", "region", "control_group", "SATMT50", "SATVR50"]].head())
# Out:
# Analysis shape: (983, 17)
#    UNITID                               INSTNM region control_group  SATMT50  \
# 0  100654             Alabama A & M University  South        Public    460.0
# 1  100663  University of Alabama at Birmingham  South        Public    620.0
# 2  100706  University of Alabama in Huntsville  South        Public    680.0
# 3  100724             Alabama State University  South        Public    477.0
# 4  100751            The University of Alabama  South        Public    640.0
#
#    SATVR50
# 0    480.0
# 1    640.0
# 2    650.0
# 3    489.0
# 4    640.0

# %% [markdown]
# ### Relationship between SAT scores and Admissions Rate (Part 1)
# These scatterplots examine the relationship between institutional SAT medians (`SATMT50`, `SATVR50`) and admission rate, with points colored by region or institution type. We include this section because our updated question asks not only whether SAT medians differ by region/type, but also whether those SAT patterns are related to admissions outcomes.
#
# Across all four plots, the dominant pattern is a negative association: institutions with higher SAT medians tend to have lower admission rates. This is visible for both Math and Verbal, and the pattern remains when points are colored by either region or control group. In practical terms, schools with higher reported SAT medians are generally more selective. Region and institution type appear to shift the concentration of points, but they do not remove the overall downward trend.
#
# The scatterplots also show substantial spread in the mid-SAT range (roughly 500–650), where admission rates vary widely across schools. That spread suggests SAT medians are related to admissions outcomes but are not the only factor. This is expected because admission rates are influenced by multiple institutional and applicant-market factors.

# %%
# MATH REGION 
sns.scatterplot(
    data=df_withoutadm,
    x='SATMT50',
    y='admit_rate',
    hue='region',  
)
plt.title('SAT math median vs admission rate(region)(figure 1)')
plt.xlabel('Median SAT Math score')
plt.ylabel('Admission Rate')
plt.legend()
plt.show()
# MATH INSTITUTION_TYPE
sns.scatterplot(
    data=df_withoutadm,
    x='SATMT50',
    y='admit_rate',
    hue='control_group',  
)
plt.title('SAT math median vs admission rate(Institution type)(figure 2)')
plt.xlabel('Median SAT Math score')
plt.ylabel('Admission Rate')
plt.legend()
plt.show()

# VERBAL REGION 
sns.scatterplot(
    data=df_withoutadm,
    x='SATVR50',
    y='admit_rate',
    hue='region',  
)
plt.title('SAT Verbal median vs admission rate(region)(Figure 3)')
plt.xlabel('Median SAT Verbal score')
plt.ylabel('Admission Rate')
plt.legend()
plt.show()

# VERBAL INSTITUTION_TYPE
sns.scatterplot(
    data=df_withoutadm,
    x='SATVR50',
    y='admit_rate',
    hue='control_group',  
)
plt.title('SAT Verbal median vs admission rate(Institution type)(figure 4)')
plt.xlabel('Median SAT Verbal score')
plt.ylabel('Admission Rate')
plt.legend()
plt.show()

from scipy.stats import pearsonr
math_r, math_p = pearsonr(df_withoutadm['SATMT50'], df_withoutadm['admit_rate'])
verbal_r, verbal_p = pearsonr(df_withoutadm['SATVR50'], df_withoutadm['admit_rate'])
print("SAT Math: ", math_r, "p-value:", math_p)
print("SAT Verbal: ", verbal_r, "p-value:", verbal_p)
# Out:
# SAT Math:  -0.6284756877312845 p-value: 3.668515795134567e-109
# SAT Verbal:  -0.5783641592958061 p-value: 7.859764834699652e-89

# %% [markdown]
# figures 1-4 Show a significant negative relationship between SAT socres and admissions rates. This shows that as SAT scores increase admission rates decrease(this is consistent across regions. We showed this numerically by conducting correlation tests. Both SAT Math and Verbal scores have a statistically significantly assosiation with admission rates(both 3.67 X 10^-109 and 7.8 X 10^-89 and < 0.05). They also have strong negative correlation. What was instresting is that math had a slightly stronger relationship, suggesting that Math SAT scores may be a better measure for potential admission into college, however further testing would be needed to determine that.

# %% [markdown]
# ## Differences by Institution Type (Part 2)
# This section uses boxplots to compare the full distribution of SAT medians across region and control_group (Public vs Private), separately for Math (SATMT50). We include this plot because mean-based summaries (like heatmaps) can hide within-group variability. Boxplots show median, interquartile range, spread, and outliers, which provides a more complete view of group differences. For SAT Math, private institutions generally have higher medians than public institutions in the Northeast, South, and West, while the Midwest appears more similar between the two groups.

# %%
sns.boxplot(
    data=df_withoutadm,
    x='region',
    y='SATMT50',
    hue= 'control_group',
    order=region_order
)
plt.title('Private and Public by region SAT comparison(figure 5)')
plt.xlabel('Region')
plt.ylabel('median math SAT score')
plt.legend()
plt.show()

## YOUR CODE HERE
import statsmodels.formula.api as smf

df_withoutadm['Private'] = df_withoutadm['control_group'].apply(
    lambda x: 0 if x == 'Public' else 1
)
model = smf.ols('admit_rate ~ SATMT50 * Private', data=df_withoutadm).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             admit_rate   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.431
# Method:                 Least Squares   F-statistic:                     248.4
# Date:                Thu, 19 Mar 2026   Prob (F-statistic):          7.54e-120
# Time:                        02:13:32   Log-Likelihood:                 320.66
# No. Observations:                 983   AIC:                            -633.3
# Df Residuals:                     979   BIC:                            -613.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4383      0.077     18.645      0.000       1.287       1.590
# ...

# %% [markdown]
# Correlation does well to show relationship, however it does not indicate where these relationships differ. By conducting linear regression analysis for the relationship between institution type admission rate and sat math scores, we found very interesting results. We use math as the results from figures 2 show math has a stronger relationship with admission rates than verbal. The interaction between SAT math scores and institution type (coef = -0.0008, p < 0.001) shows that SAT scores for public and private schools have different effects on admissions. Looking further into this we find that the slope -0.0012(public institutions) is less steep than the slope -0.0020(private institutions) found by subtracting -0.0012 by 0.0008. What this tells us is that admission rates decrease at a faster rate as SAT scores increase for private institutions, in other words selectivity in private institutions is more reliant on SAT scores than in public universities. The results support our hypothesis that for public and private institutions the relationship between SAT scores and admissions outcomes is different.

# %% [markdown]
# ## Regional Differences in SAT Scores(Part 3)
# These heatmaps are a compact summary of group-level SAT outcomes, using mean SATMT50 and mean SATVR50 for each region × control_group combination.
#
# Several patterns are clear. Private institutions have higher average SAT medians than public institutions in most regions, with the largest gaps in the Northeast and West. The South has the lowest mean levels for both SAT Math and SAT Verbal among the four regions, while Northeast/West private institutions have the highest means. Midwest appears closer between public and private than other regions, especially for verbal scores. These patterns suggest that both region and institution type are associated with SAT median levels, and that the strength of the public-private gap may vary by region.
#
# In context, these are descriptive means, so they should be interpreted as a high-level signal rather than final evidence. Mean-based summaries can hide within-group spread and outliers, which is why we must corroborate with statistical tests and informatino from earlier. Also, because this dataset is filtered to institutions with available SAT medians, these averages reflect the reporting sample, not all U.S. institutions.

# %%
# Heatmaps for compact summary
mean_math = df_withoutadm.pivot_table(index="region", columns="control_group", values="SATMT50", aggfunc="mean").loc[region_order, control_order]
mean_verbal = df_withoutadm.pivot_table(index="region", columns="control_group", values="SATVR50", aggfunc="mean").loc[region_order, control_order]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

sns.heatmap(mean_math, annot=True, fmt=".1f", cmap="YlGnBu", ax=axes[0])
axes[0].set_title("Mean SAT Math Median(figure 6)")
axes[0].set_xlabel("Institution Type")
axes[0].set_ylabel("Region")

sns.heatmap(mean_verbal, annot=True, fmt=".1f", cmap="YlOrRd", ax=axes[1])
axes[1].set_title("Mean SAT Verbal Median(figure 7)")
axes[1].set_xlabel("Institution Type")
axes[1].set_ylabel("Region")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_418/1627318358.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   mean_math = df_withoutadm.pivot_table(index="region", columns="control_group", values="SATMT50", aggfunc="mean").loc[region_order, control_order]
# /tmp/ipykernel_418/1627318358.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   mean_verbal = df_withoutadm.pivot_table(index="region", columns="control_group", values="SATVR50", aggfunc="mean").loc[region_order, control_order]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

##Math
df_inst_x_region = df_withoutadm[['SATMT50', 'region', 'control_group']] 
model = ols('SATMT50 ~ C(region) * C(control_group)', data=df_inst_x_region).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("Math:", anova_table)
##Verbal
df_inst_x_region = df_withoutadm[['SATVR50', 'region', 'control_group']] 
model = ols('SATVR50 ~ C(region) * C(control_group)', data=df_inst_x_region).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("verbal:", anova_table)
# Out:
# Math:                                   sum_sq     df          F        PR(>F)
# C(region)                   5.658847e+05    3.0  34.864906  2.085070e-21
# C(control_group)            1.844285e+05    1.0  34.088652  7.166293e-09
# C(region):C(control_group)  1.132101e+05    3.0   6.975026  1.206834e-04
# Residual                    5.275004e+06  975.0        NaN           NaN
# verbal:                                   sum_sq     df          F        PR(>F)
# C(region)                   4.618625e+05    3.0  35.666265  7.121048e-22
# C(control_group)            1.651382e+05    1.0  38.257250  9.110543e-10
# C(region):C(control_group)  8.197701e+04    3.0   6.330485  2.980706e-04
# Residual                    4.208608e+06  975.0        NaN           NaN

# %% [markdown]
# Figures 7 and 8 show that SAT scores vary across region and Institution type In specific we see that the Northeast and West have significant differences. Using a two factor anova test, we find our first important result when looking at how SAT medieans differ across regions and across institution types. looking at these statistics here: Region: (Math:(F = 34.86, P-Value < 0.001) Verbal:(F=35.67, P-Value < 0.001) and then Institution type: ((Math:(F = 34.09, P-Value < 0.001) Verbal:(F=38.26, P-Value < 0.001). What this tells us is SAT splits do indeed vary across both region and institution type.
#
# We then use means find the direction of these variances. In all regions for the exception of the midwest which shows little to no differences, Private institutions show higher SAT scores than public institutions. This is most prominant in the West with a private being 50 points greater on average for both math and verbal. This interaction is further backed found by the results of the two way anova: SAT Math (F = 6.98, p < 0.001) and SAT Verbal (F = 6.33, p < 0.001). This tells us that there is not a consistant variance between public and private institutes across regions. Instead the difference of SAT score between public and private instutions is different across different regions. These findings support our hypothesis that SAT scores differ across regions however they are not consistent nationwide.

# %% [markdown]
# # OLD

# %% [markdown]
# ### Geographic Patterns in State-Level SAT Median Averages
# These choropleth maps provide geographic context by showing state-level averages of institutional SAT medians (`SATMT50` and `SATVR50`). The purpose is to complement region-level comparisons with a finer spatial view and check whether broad regional patterns are concentrated in specific states or more widely distributed.
#
# Both maps suggest that higher state-average SAT medians are more common in parts of the Northeast and West, while several interior and southern states show lower averages. The math and verbal maps are directionally consistent, which supports the earlier finding that regional differences appear in both SAT sections rather than only one.
#
# These maps are descriptive summaries and should be interpreted carefully. Each state value is an average across institutions in our filtered sample, so states with fewer reporting schools may be less stable, and within-state variation is not shown. Even with that limitation, the spatial distribution aligns with earlier boxplot and heatmap results and strengthens the case that geography is an important dimension in SAT median patterns.`m

# %%
# !pip install kaleido==0.2.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 28.0 MB/s eta 0:00:0000:0100:01m
# ...

# %%
import plotly.express as px
from IPython.display import Image, display


state_sat = (
    df_withoutadm
    .groupby("STABBR", as_index=False)[["SATMT50", "SATVR50"]]
    .mean()
)

fig_math = px.choropleth(
    state_sat,
    locations="STABBR",
    locationmode="USA-states",
    color="SATMT50",
    scope="usa",
    color_continuous_scale="Blues",
    title="State Average SAT Math Median"
)
fig_math.write_image("sat_math_choropleth.png")
display(Image("sat_math_choropleth.png"))

fig_verbal = px.choropleth(
    state_sat,
    locations="STABBR",
    locationmode="USA-states",
    color="SATVR50",
    scope="usa",
    color_continuous_scale="Reds",
    title="State Average SAT Verbal Median"
)
fig_verbal.write_image("sat_verbal_choropleth.png")
display(Image("sat_verbal_choropleth.png"))

# %% [markdown]
# Due to the amount of datapoints we have there are countless plots we could go with. line plots that tackle admission between regions. scatter plots to show correlation between accpetance rate and sat composite scores, is acceptance rate of private vs public school in a state weighed more heavily by math or writing sat scores with another scatterplot. All of these can end up contributing to finding an aswer to how admissions are effected between regions based on sat writing and math scores in public and private institutions.

# %% [markdown]
# ### ETC AD NASEUM
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
